# %%
import pandas as pd

data = pd.read_json("alldrugsprops.json")
data.head()
# Out:
#                                               SMILES        MR     LOGP  HBD  \
# 0  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...  539.8094 -8.11643   28
# 1  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...  328.5382 -3.10570   17
# 2  CC(C)C[C@@H](NC(=O)CNC(=O)[C@@H](NC=O)C(C)C)C(...  500.1181  4.86760   20
# 3  NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...  271.4037 -4.13203   14
# 4  CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...  377.7252 -0.50613   17
#
#    HBA     PSA  ROTB  AROM      FSP3  FC       QED    ALOGP
# 0   29  901.57    66     3  0.540816   0  0.014176 -8.11643
# 1   16  495.89    31     4  0.508475   0  0.010267 -3.10570
# 2   16  519.89    51     8  0.510417   0  0.022619  4.86760
# 3   15  435.41    19     2  0.478261   0  0.027501 -4.13203
# 4   16  495.67    38     5  0.428571   0  0.013447 -0.50613
